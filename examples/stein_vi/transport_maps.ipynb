# %% [markdown]
# # Transport maps (Triangular, NeuTra)
# Based on "Transport map accelerated Markov chain Monte Carlo" by Parno and Marzouk (SIAM/ASA Journal on Uncertainty Quantification 2018) and "NeuTra-lizing Bad Geometry in Hamiltonian Monte Carlo Using Neural Transport" by Hoffman et al. (Symposium on Approximate Bayesian Inference 2018)

# %%
import jax
import jax.numpy as np
import numpy as onp
import numpyro
from numpyro import distributions as dist
from numpyro.distributions import constraints
from numpyro.examples.runge_kutta import runge_kutta_4
from tqdm import tqdm

# %%
rng_key = jax.random.PRNGKey(242)

# %% [markdown]
# ## Predator Prey Model

# %%
def predator_prey(t, state, r=0.6, k=100, s=1.2, a=25, u=0.5, v=0.3):
    prey = state[..., 0]
    predator = state[..., 1]
    sh = (prey * predator)/(a + prey)
    prey_upd = r * prey * (1 - prey / k) - s * sh
    predator_upd = u * sh - v * predator
    return np.stack((prey_upd, predator_upd), axis=-1)

# %%
indices = np.array([1, 11, 21, 31, 41])
res = runge_kutta_4(predator_prey, np.array([50., 5.]), 0.1, 50)
noise = jax.random.normal(rng_key, (1000,5,2)) * 10
data = (indices, res[indices] + noise)
data
# Out:
# (DeviceArray([ 1, 11, 21, 31, 41], dtype=int32),
#  DeviceArray([[[ 39.024696 , -12.725592 ],
#                [ 66.320984 ,   6.957094 ],
#                [ 68.026535 ,   3.555342 ],
#                [ 91.41165  ,  12.742411 ],
#                [ 72.754944 ,  -2.7839265]],
#
#               [[ 70.52715  ,   8.503686 ],
#                [ 82.815445 ,   7.1307592],
#                [ 47.49247  ,  -3.0286903],
#                [ 79.045616 ,  12.486261 ],
#                [ 61.746765 ,   7.427475 ]],
#
#               [[ 44.7713   ,  -8.647638 ],
#                [ 68.058876 ,  10.351557 ],
#                [ 62.73179  ,  20.398611 ],
#                [ 76.33872  ,  24.19844  ],
#                [ 68.47187  ,  11.550174 ]],
#
#               ...,
#
#               [[ 65.181244 ,  17.313402 ],
#                [ 62.664757 ,   5.912359 ],
#                [ 77.01439  ,   7.073277 ],
#                [ 80.45603  ,  16.42875  ],
#                [ 73.00238  ,   4.452697 ]],
#
#               [[ 60.07134  ,  -6.554132 ],
#                [ 60.279194 , -11.933813 ],
#                [ 65.92108  ,  19.284107 ],
#                [ 74.64605  ,  13.780729 ],
#                [ 77.26826  ,  15.895439 ]],
#
#               [[ 43.870888 ,  -1.1976914],
#                [ 42.344887 ,  10.72414  ],
#                [ 78.40987  ,   6.6342463],
#                [ 82.94648  ,  -0.2914729],
#                [ 57.540928 ,  16.0469   ]]], dtype=float32))

# %%
# %%
def model(indices, observations):
    prey0 = numpyro.sample('prey0', dist.Uniform(0.1, 50.))
    predator0 = numpyro.sample('predator0', dist.Uniform(0.1, 50.))
    r = numpyro.sample('r', dist.Uniform(0.1, 50.))
    k = numpyro.sample('k', dist.Uniform(0.1, 150.))
    s = numpyro.sample('s', dist.Uniform(0.1, 50.))
    a = numpyro.sample('a', dist.Uniform(0.1, 50.))
    u = numpyro.sample('u', dist.Uniform(0.1, 50.))
    v = numpyro.sample('v', dist.Uniform(0.1, 50.))
    stddev = numpyro.sample('stddev', dist.InverseGamma(1.))
    ppres = runge_kutta_4(lambda t, state: predator_prey(t, state, r, k, s, a, u, v),
                          np.array([prey0, predator0]), 0.01, 50)
    numpyro.sample('obs', dist.Normal(ppres[indices], stddev).to_event(2), obs=observations)

# %% [markdown]
# ### NUTS MCMC Sampling

# %%
mcmc = numpyro.infer.MCMC(numpyro.infer.NUTS(model), 100, 1000, num_chains=2, chain_method='sequential')
mcmc.run(rng_key, *data)
mcmc.print_summary()
# Out:
# sample: 100%|██████████| 1100/1100 [00:56<00:00, 19.34it/s, 511 steps of size 2.00e-03. acc. prob=0.93]
# sample: 100%|██████████| 1100/1100 [00:26<00:00, 41.55it/s, 575 steps of size 4.63e-03. acc. prob=0.83]
#
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
#           a     24.39     14.84     24.59      0.13     44.92    127.62      1.01
#           k    105.48     11.03    103.96     88.85    121.91    112.86      1.05
#   predator0      5.34      0.28      5.34      4.91      5.82   1289.45      1.00
#       prey0     49.85      0.14     49.89     49.66     50.00   1328.83      1.00
#           r      6.68      1.13      6.45      5.10      8.37    173.96      1.04
#           s     19.45     13.50     17.08      0.10     40.82    119.50      1.05
#      stddev     10.12      0.07     10.12     10.01     10.24   2184.77      1.00
#           u      9.23      9.54      5.84      0.34     20.89     89.78      1.01
#           v      7.02      9.09      3.69      0.10     17.44     83.13      1.01
#
# Number of divergences: 89

# %% [markdown]
# ### Guide and Stein with Transport Maps

# %%
def standard_guide(indices, observations):
    prey0val = numpyro.param('prey0val', 25, constraint=constraints.interval(0.1, 50))
    prey0 = numpyro.sample('prey0', dist.Delta(prey0val))
    predator0val = numpyro.param('predator0val', 25, constraint=constraints.interval(0.1, 50))
    predator0 = numpyro.sample('predator0', dist.Delta(predator0val))
    rval = numpyro.param('rval', 25, constraint=constraints.interval(0.1, 50))
    r = numpyro.sample('r', dist.Delta(rval))
    kval = numpyro.param('kval', 25, constraint=constraints.interval(0.1, 50))
    k = numpyro.sample('k', dist.Delta(kval))
    sval = numpyro.param('sval', 25, constraint=constraints.interval(0.1, 50))
    s = numpyro.sample('s', dist.Delta(sval))
    aval = numpyro.param('aval', 25, constraint=constraints.interval(0.1, 50))
    a = numpyro.sample('a', dist.Delta(aval))
    uval = numpyro.param('uval', 25, constraint=constraints.interval(0.1, 50))
    u = numpyro.sample('u', dist.Delta(uval))
    vval = numpyro.param('vval', 25, constraint=constraints.interval(0.1, 50))
    v = numpyro.sample('v', dist.Delta(vval))

# %%
svgd = numpyro.infer.SVGD(model, numpyro.guides.WrappedGuide(standard_guide), 
                          numpyro.optim.SGD(1e-100), numpyro.infer.ELBO(),
                          numpyro.infer.kernels.RBFKernel(), repulsion_temperature=data[1].shape[0])
state, loss = svgd.run(rng_key, 100000, *data)
# Out:
# SVGD 1.929e+05: 100%|██████████| 100000/100000 [03:11<00:00, 522.46it/s]

# %%
def transmap_guide(indices, observations):
    prey0val = numpyro.param('prey0val', 25)
    predator0val = numpyro.param('predator0val', 25)
    rval = numpyro.param('rval', 25)
    kval = numpyro.param('kval', 25)
    sval = numpyro.param('sval', 25)
    aval = numpyro.param('aval', 25)
    uval = numpyro.param('uval', 25)
    vval = numpyro.param('vval', 25)
    tmapp = numpyro.param('tmapp', np.zeros(8 * (8 + 1) // 2) + 1e-3)
    tril_idx = np.tril_indices(8)
    tmap = jax.ops.index_update(np.zeros((8, 8)), tril_idx, tmapp)
    prey0val, predator0val, rval, kval, sval, aval, uval, vval = tmap @ np.array([prey0val, predator0val, rval, kval, sval, aval, uval, vval])
    prey0 = numpyro.sample('prey0', dist.Delta(prey0val))
    predator0 = numpyro.sample('predator0', dist.Delta(predator0val))
    r = numpyro.sample('r', dist.Delta(rval))
    k = numpyro.sample('k', dist.Delta(kval))
    s = numpyro.sample('s', dist.Delta(sval))
    a = numpyro.sample('a', dist.Delta(aval))
    u = numpyro.sample('u', dist.Delta(uval))
    v = numpyro.sample('v', dist.Delta(vval))

# %%
svgd = numpyro.infer.SVGD(model, numpyro.guides.WrappedGuide(transmap_guide), 
                          numpyro.optim.SGD(1e-100), numpyro.infer.ELBO(),
                          numpyro.infer.kernels.RBFKernel(), repulsion_temperature=data[1].shape[0],
                          classic_guide_params_fn=lambda n: n in {'tmapp'})
with jax.disable_jit():
    state, loss = svgd.run(rng_key, 100000, *data)
# Out:
# 0%|          | 0/100000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-a48262365e69> in <module>
#       4                           classic_guide_params_fn=lambda n: n in {'tmapp'})
#       5 with jax.disable_jit():
# ----> 6     state, loss = svgd.run(rng_key, 100000, *data)
#
# ~/Documents/SourceControl/numpyro/numpyro/infer/stein.py in run(self, rng_key, num_steps, return_last, progbar, *args, **kwargs)
#     298             with tqdm.trange(num_steps) as t:
#     299                 for i in t:
# --> 300                     svgd_state, losses = jax.jit(bodyfn)(i, (svgd_state, losses))
#     301                     t.set_description('SVGD {:.5}'.format(losses[i]), refresh=False)
#     302                     t.update()
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     129   def f_jitted(*args, **kwargs):
#     130     if _thread_local_state.jit_is_disabled or config.read('jax_disable_jit'):
# --> 131       return fun(*args, **kwargs)
#     132     if static_argnums and max(static_argnums) >= len(args):
#     133       msg = ("Jitted function has static_argnums={} but was called with only {}"
#
# ~/Documents/SourceControl/numpyro/numpyro/infer/stein.py in bodyfn(i, info)
#     288         def bodyfn(i, info):
#     289             svgd_state, losses = info
# --> 290             svgd_state, loss = self.update(svgd_state, *args, **kwargs)
#     291             losses = ops.index_update(losses, i, loss)
#     292             return svgd_state, losses
#
# ~/Documents/SourceControl/numpyro/numpyro/infer/stein.py in update(self, state, *args, **kwargs)
#     280         else:
#     281             optim_state = state.optim_state
# --> 282         loss_val, grads = self._svgd_loss_and_grads(rng_key_step, params,
#     283                                                     *args, **kwargs, **self.static_kwargs)
#     284         optim_state = self.optim.update(grads, optim_state)
#
# ~/Documents/SourceControl/numpyro/numpyro/infer/stein.py in _svgd_loss_and_grads(self, rng_key, unconstr_params, *args, **kwargs)
#     135
#     136         kernel_particle_loss_fn = lambda ps: scaled_loss(rng_key, self.constrain_fn(classic_uparams), self.constrain_fn(unravel_pytree(ps)))
# --> 137         loss, particle_ljp_grads = jax.vmap(jax.value_and_grad(kernel_particle_loss_fn))(stein_particles)
#     138         classic_param_grads = jax.vmap(lambda ps: jax.grad(lambda cps:
#     139                                             scaled_loss(rng_key, self.constrain_fn(cps), self.constrain_fn(unravel_pytree(ps))))(classic_uparams))(stein_particles)
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/api.py in batched_fun(*args)
#     689     in_axes_flat = _flatten_axes(in_tree, in_axes)
#     690     _check_axis_sizes(in_tree, args_flat, in_axes_flat)
# --> 691     out_flat = batching.batch(flat_fun, args_flat, in_axes_flat,
#     692                               lambda: _flatten_axes(out_tree(), out_axes))
#     693     return tree_unflatten(out_tree(), out_flat)
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/interpreters/batching.py in batch(fun, in_vals, in_dims, out_dim_dests)
#      35 def batch(fun, in_vals, in_dims, out_dim_dests):
#      36   size, = {x.shape[d] for x, d in zip(in_vals, in_dims) if d is not not_mapped}
# ---> 37   out_vals, out_dims = batch_fun(fun, in_vals, in_dims)
#      38   return map(partial(matchaxis, size), out_dims, out_dim_dests(), out_vals)
#      39
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/interpreters/batching.py in batch_fun(fun, in_vals, in_dims)
#      41   with new_master(BatchTrace) as master:
#      42     fun, out_dims = batch_subtrace(fun, master, in_dims)
# ---> 43     out_vals = fun.call_wrapped(*in_vals)
#      44     del master
#      45   return out_vals, out_dims()
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     147     gen = None
#     148
# --> 149     ans = self.f(*args, **dict(self.params, **kwargs))
#     150     del args
#     151     while stack:
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     405     f_partial, dyn_args = _argnums_partial(f, argnums, args)
#     406     if not has_aux:
# --> 407       ans, vjp_py = vjp(f_partial, *dyn_args)
#     408     else:
#     409       ans, vjp_py, aux = vjp(f_partial, *dyn_args, has_aux=True)
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/api.py in vjp(fun, *primals, **kwargs)
#    1283   if not has_aux:
#    1284     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1285     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1286     out_tree = out_tree()
#    1287   else:
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     104 def vjp(traceable, primals, has_aux=False):
#     105   if not has_aux:
# --> 106     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     107   else:
#     108     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      93   _, in_tree = tree_flatten(((primals, primals), {}))
#      94   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# ---> 95   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#      96   pval_primals, pval_tangents = tree_unflatten(out_tree(), out_pvals)
#      97   aval_primals, const_primals = unzip2(pval_primals)
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate, stage_out_calls)
#     352   with new_master(trace_type) as master:
#     353     fun = trace_to_subjaxpr(fun, master, instantiate)
# --> 354     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     355     assert not env
#     356     del master
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     147     gen = None
#     148
# --> 149     ans = self.f(*args, **dict(self.params, **kwargs))
#     150     del args
#     151     while stack:
#
# ~/Documents/SourceControl/numpyro/numpyro/infer/stein.py in <lambda>(ps)
#     134             return - loss_val
#     135
# --> 136         kernel_particle_loss_fn = lambda ps: scaled_loss(rng_key, self.constrain_fn(classic_uparams), self.constrain_fn(unravel_pytree(ps)))
#     137         loss, particle_ljp_grads = jax.vmap(jax.value_and_grad(kernel_particle_loss_fn))(stein_particles)
#     138         classic_param_grads = jax.vmap(lambda ps: jax.grad(lambda cps:
#
# ~/Documents/SourceControl/numpyro/numpyro/infer/stein.py in scaled_loss(rng_key, classic_params, stein_params)
#     131         def scaled_loss(rng_key, classic_params, stein_params):
#     132             params = {**classic_params, **stein_params}
# --> 133             loss_val = self.loss.loss(rng_key, params, handlers.scale(self.model, self.loss_temperature), self.guide, *args, **kwargs, **self.static_kwargs)
#     134             return - loss_val
#     135
#
# ~/Documents/SourceControl/numpyro/numpyro/infer/elbo.py in loss(self, rng_key, param_map, model, guide, *args, **kwargs)
#      68         # the ELBO is a lower bound that needs to be maximized.
#      69         if self.num_particles == 1:
# ---> 70             return - single_particle_elbo(rng_key)
#      71         else:
#      72             rng_keys = random.split(rng_key, self.num_particles)
#
# ~/Documents/SourceControl/numpyro/numpyro/infer/elbo.py in single_particle_elbo(rng_key)
#      57             seeded_model = seed(model, model_seed)
#      58             seeded_guide = seed(guide, guide_seed)
# ---> 59             guide_log_density, guide_trace = log_density(seeded_guide, args, kwargs, param_map)
#      60             seeded_model = replay(seeded_model, guide_trace)
#      61             model_log_density, _ = log_density(seeded_model, args, kwargs, param_map)
#
# ~/Documents/SourceControl/numpyro/numpyro/infer/util.py in log_density(model, model_args, model_kwargs, params, skip_dist_transforms)
#      60     else:
#      61         model = substitute(model, param_map=params)
# ---> 62     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#      63     log_joint = jax.device_put(0.)
#      64     for site in model_trace.values():
#
# ~/Documents/SourceControl/numpyro/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     147         :return: `OrderedDict` containing the execution trace.
#     148         """
# --> 149         self(*args, **kwargs)
#     150         return self.trace
#     151
#
# ~/Documents/SourceControl/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      63     def __call__(self, *args, **kwargs):
#      64         with self:
# ---> 65             return self.fn(*args, **kwargs)
#      66
#      67
#
# ~/Documents/SourceControl/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      63     def __call__(self, *args, **kwargs):
#      64         with self:
# ---> 65             return self.fn(*args, **kwargs)
#      66
#      67
#
# ~/Documents/SourceControl/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      63     def __call__(self, *args, **kwargs):
#      64         with self:
# ---> 65             return self.fn(*args, **kwargs)
#      66
#      67
#
# ~/Documents/SourceControl/numpyro/numpyro/guides/__init__.py in __call__(self, *args, **kwargs)
#      54
#      55     def __call__(self, *args, **kwargs):
# ---> 56         return self.fn(*args, **kwargs)
#
# <ipython-input-14-3d01e1a79a7c> in transmap_guide(indices, observations)
#      10     tmapp = numpyro.param('tmapp', np.zeros(8 * (8 + 1) // 2) + 1e-3)
#      11     tril_idx = np.tril_indices(8)
# ---> 12     tmap = jax.ops.index_update(np.zeros((8, 8)), tril_idx, tmapp)
#      13     prey0val, predator0val, rval, kval, sval, aval, uval, vval = tmap @ np.array([prey0val, predator0val, rval, kval, sval, aval, uval, vval])
#      14     prey0 = numpyro.sample('prey0', dist.Delta(prey0val))
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/ops/scatter.py in index_update(x, idx, y)
#     244          [1., 1., 1., 6., 6., 6.]], dtype=float32)
#     245   """
# --> 246   return _scatter_update(x, idx, y, lax.scatter)
#     247
#     248 def segment_sum(data, segment_ids, num_segments=None):
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/ops/scatter.py in _scatter_update(x, idx, y, scatter_op)
#      52   # is more or less a transpose of the gather equivalent.
#      53   treedef, static_idx, dynamic_idx = np._split_index_for_jit(idx)
# ---> 54   return _scatter_impl(x, y, scatter_op, treedef, static_idx, dynamic_idx)
#      55
#      56
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/ops/scatter.py in _scatter_impl(x, y, scatter_op, treedef, static_idx, dynamic_idx)
#      65
#      66   # Broadcast `y` to the slice output shape.
# ---> 67   y = np.broadcast_to(y, tuple(indexer.slice_shape))
#      68   # Collapse any `None`/`np.newaxis` dimensions.
#      69   y = np.squeeze(y, axis=indexer.newaxis_dims)
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/numpy/lax_numpy.py in broadcast_to(arr, shape)
#    1110     if nlead < 0 or not onp.all(compatible):
#    1111       msg = "Incompatible shapes for broadcasting: {} and requested shape {}"
# -> 1112       raise ValueError(msg.format(arr_shape, shape))
#    1113     diff, = onp.where(onp.not_equal(shape[nlead:], arr_shape))
#    1114     new_dims = tuple(range(nlead)) + tuple(nlead + diff)
#
# ValueError: Incompatible shapes for broadcasting: (10, 36) and requested shape (36,)
